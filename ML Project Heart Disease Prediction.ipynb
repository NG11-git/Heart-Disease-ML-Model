# %% [markdown]
# # Project : HeartDiseasePrediction

# %%
# for data prepration 
import pandas as pd

# for plotting and chart
#import matplotlib.pyplot as plt 
#import seaborn as sns

# for data sampling
from sklearn.model_selection import train_test_split

# for confusion matrix, accuracy, Precision, and recall
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv(r'heart dataset.csv')

# %%
df.shape # observation 303, variables 14
# Out:
# (1025, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df['thal'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
# create x and y
x=df.drop("target", axis=1)
y=df["target"]

# %% [markdown]
# # Training and Testing

# %%
xtrain, xtest, ytrain, ytest=train_test_split(x,y, test_size=0.2, 
                                              random_state=2)

# %%
print(xtrain.columns)
# Out:
# Index(['age', 'sex', 'pain', 'BP', 'chol', 'fbs', 'ecg', 'maxhr', 'eiang',
#        'eist', 'slope', 'vessels', 'thal'],
#       dtype='object')

# %%
#check sample size
print(xtrain.shape, xtest.shape, ytrain.shape, ytest.shape)

# %% [markdown]
# # SVM (Support Vector Machine) Algorithm

# %%
#Fit the model
svm=SVC(kernel='linear')
svm.fit(xtrain,ytrain)
# Out:
# SVC(kernel='linear')

# %%
#Predict the response from xtest
svm_predicted=svm.predict(xtest)

# %%
#check scores
svm_accuracy=accuracy_score(ytest, svm_predicted)
svm_precision=precision_score(ytest, svm_predicted)
svm_recall=recall_score(ytest, svm_predicted)
svm_fscore=f1_score(ytest, svm_predicted)

# %%
# update accuracy tables
col=['Model','Accuracy',  'Precision','Recall', 'F1-Score']
data=[
     ["SVM", svm_accuracy,svm_precision, svm_recall,svm_fscore]]
ml_summary=pd.DataFrame(data, columns=col)
ml_summary
# Out:
#   Model  Accuracy  Precision  Recall  F1-Score
# 0   SVM  0.829268   0.768595    0.93  0.841629

# %% [markdown]
# # LogisticRegression

# %%
# fit the training model
log=LogisticRegression()
log.fit(xtrain,ytrain)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# test the model using xtest
Log_predicted=pipe_3.predict(xtest)

# %%
Log_accuracy=accuracy_score(ytest, Log_predicted)
Log_precision=precision_score(ytest, Log_predicted)
Log_recall=recall_score(ytest, Log_predicted)
Log_fscore=f1_score(ytest, Log_predicted)

# %%
# update accuracy tables
col=['Model','Accuracy',  'Precision','Recall', 'F1-Score']
data=[
     ["SVM", svm_accuracy,svm_precision, svm_recall,svm_fscore],
     ["LogisticRegression", Log_accuracy, Log_precision, Log_recall, Log_fscore]]
ml_summary=pd.DataFrame(data, columns=col)
ml_summary
# Out:
#                 Model  Accuracy  Precision  Recall  F1-Score
# 0                 SVM  0.829268   0.768595    0.93  0.841629
# 1  LogisticRegression  0.873171   0.824561    0.94  0.878505

# %%
# best performd model is logisticreg

# %%
# create a pickle file using seralization

# %%
import joblib

# %%
joblib.dump(svm, "svm.joblib")
# Out:
# ['svm.joblib']

# %%
joblib.dump(log, "log.joblib")
# Out:
# ['log.joblib']

# %%
# building predicting
import numpy as np
input_data=(67,0,0,106,223,0,1,142,0,0.3,2,2,2)
input_data_as_numpy_array=np.asarray(input_data)
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction = svm.predict(input_data_reshaped)
if (prediction[0] == 0):
    print('The person does not have heart disease')
else:
    print('The person does have heart disease')
# Out:
# The person does have heart disease
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
